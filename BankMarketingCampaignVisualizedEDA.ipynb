# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import warnings
import xlrd
warnings.filterwarnings('ignore')
# %matplotlib inline

df = pd.read_csv('BankMarketingVis.csv')
dfbin = pd.read_csv('BankMarketingBinVis.csv')

# %% [markdown]
# # Data Information

# %% [markdown]
# **This data was taken from May 2008 to November 2010**

# %%
img1 = mpimg.imread('Image/DataInfoUCI.png')

plt.figure(figsize=(16, 16))
plt.title('Data Info')
plt.axis('off')
imgplot = plt.imshow(img1)

# %% [markdown]
# # Economic Landscape
#
# **World Financial Crisis Affects Portugal From Late 2008, Peaking on 2009**
#
# **On 2010, Portugal Starts Recovering**

# %%
img2 = mpimg.imread('Image/PortugalGDPCapita.png')
img3 = mpimg.imread('Image/PortugalGDPChange.png')

plt.figure(figsize=(12, 6))
plt.axis('off')
imgplot = plt.imshow(img2)
plt.title('Portugal GDP Per Capita')
plt.show()
print('Source World Bank')

plt.figure(figsize=(12, 6))
plt.axis('off')
plt.title('Portugal GDP Growth')
imgplot = plt.imshow(img3)
plt.show()
print('Source World Bank')
# Out:
# Source World Bank
# Source World Bank

# %%
img4 = mpimg.imread('Image/PortugalSavingRate.png')
img5 = mpimg.imread('Image/PortugalNPL.png')

plt.figure(figsize=(16, 10))
plt.axis('off')
imgplot = plt.imshow(img4)
plt.show()

plt.figure(figsize=(16, 14))
plt.axis('off')
plt.title('Portugal Non-Performing-Loan')
imgplot = plt.imshow(img5)
plt.show()
print('Source World Bank')
# Out:
# Source World Bank

# %% [markdown]
# # Challanges
#
# - **During economic crisis :**
#     - companies including banks need to spend their capital wisely in order to survive the cycle
#     - banks often experience liquidity problems, due to massive numbers of customers cashing-out their money
#     - the problems often gets severe, since there might be a spike in non-performing-loan credits
#     - therefore, banks need as much deposits as possible from customers, but should keep maintaining it's cost
#
# # Deposits Marketing
#
# - **Offering term deposits to all clients will be inneficient and costly**
#
#
# - **Clients with certain features, are less potential clients to place a term deposits**
#
#
# - **Banks need to classify wether the customer has a high or low potential on placing a term deposits**
#
#
# # Focus Problems
#
# ### Customers Saving Rates Drop Significantly During Crisis, But The Marketing Cost Are Still High
#
# ### Bank Has To Cut Marketing Expenses

# %% [markdown]
# # Analysis on Customers

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,3,1)
sns.barplot(data = dfbin, x=dfbin['AgeGroup'], y =dfbin['Success'])
plt.subplot(1,3,2)
sns.barplot(data = dfbin, x=dfbin['EducationLevel'], y =dfbin['Success'])
plt.subplot(1,3,3)
sns.barplot(data = df, x=df['Marital'], y =df['Success'])

# %% [markdown]
# **Elders Are The Most Likely to Put A Term Deposits, This Due To A Much Higher Savings Rate Among Elders Compare to Other Age Groups**
#
# **People With Higher Education, Slightly More Likely To Put A Term Deposits, But The Differences Is Still Small Compared to Other Eurozone Countries**
#
# **Single Customers Are The Most Likely To Put A Term Deposits, This Due To Higher Saving Rate Of Single Compare To Married And Divorced Customers**
#
#     This Due To Higher Spending Rate For Married Couple, Especially Families With Children

# %%
img6 = mpimg.imread('Image/PortugalSavingRateByAge.png')
img7 = mpimg.imread('Image/PortugalSavingRateByFamily.png')

plt.figure(figsize=(16, 16))
plt.subplot(1,2,1)
plt.axis('off')
imgplot = plt.imshow(img6)
plt.subplot(1,2,2)
plt.axis('off')
imgplot = plt.imshow(img7)
plt.show()

# %%
img8 = mpimg.imread('Image/PortugalSavingRateByEducation1.png')
img9 = mpimg.imread('Image/PortugalSavingRateByEducation2.png')

plt.figure(figsize=(16, 16))
plt.subplot(1,2,1)
plt.axis('off')
plt.title('Portugal Saving Rate By Education')
imgplot = plt.imshow(img8)
plt.subplot(1,2,2)
plt.axis('off')
plt.title('Eurozone Saving Rate And Higher Education')
imgplot = plt.imshow(img9)
plt.show()

# %% [markdown]
# # Analysis on Customers Loan

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,3,1)
sns.barplot(data = df, x=df['HousingLoan'], y =df['Success'])
plt.subplot(1,3,2)
sns.barplot(data = df, x=df['HasLoan'], y =df['Success'])
plt.subplot(1,3,3)
sns.barplot(data = df, x=df['HasDefault'], y =df['Success'])

# %% [markdown]
# **There Is No Significant Differences on Successful Campaign Rate Between Customers With Loans And Customers With No Loans**

# %% [markdown]
# # Analysis on Customers Job

# %%
plt.figure(figsize=(16,10))
plt.subplot(3,1,1)
sns.barplot(data = df, x=df['Job'], y =df['Success'])
plt.subplot(3,1,2)
sns.barplot(data = df, x=df['Job'], y =df['Age'])
plt.subplot(3,1,3)
sns.barplot(data = dfbin, x=dfbin['AllJob'], y =dfbin['EducationLevelNum'])

# %%
img8 = mpimg.imread('Image/PortugalJobIncome.png')
img9 = mpimg.imread('Image/PortugalJobIncomeSource.png')

plt.figure(figsize=(16, 20))
plt.subplot(2,1,1)
plt.axis('off')
plt.title('Portugal Income By Job')
imgplot = plt.imshow(img8)
plt.subplot(2,1,2)
plt.axis('off')
imgplot = plt.imshow(img9)
plt.show()

# %%
img10 = mpimg.imread('Image/ChildEduFamilyWealth.png')

plt.figure(figsize=(16, 16))
plt.subplot(1,1,1)
plt.axis('off')
plt.title('World Child Education By Family Wealth')
imgplot = plt.imshow(img10)
plt.show()

# %% [markdown]
# # Analysis on Customers Contact

# %%
plt.figure(figsize=(15,4))

plt.subplot(1,2,1)
sns.barplot(data = df, x=df['ContactType'], y =df['Success'])
plt.subplot(1,2,2)
sns.barplot(data = df, x=df['PreviousOutcome'], y =df['Success'])

# %% [markdown]
# **On Average, Celullar Are More Effective For Marketings Compared With Telephone**
#
#     More Info :
#     https://smallbusiness.chron.com/direct-email-can-effective-new-customer-27635.html
#
# **Customers With Deals on Previous Campaigns, Are More Potential To Put A Term Deposits**
#
#     Customers Put A Term Deposits on Previous Campaigns Are Proven To Have A Records on Putting Term Deposits

# %% [markdown]
# # Analysis on Campaigns

# %%
plt.figure(figsize=(15,4))

plt.subplot(1,2,1)
sns.barplot(data = dfbin, x=dfbin['ThisCampaignContactBin'], y =dfbin['Success'])
plt.subplot(1,2,2)
sns.barplot(data = dfbin, x=dfbin['PreviousCampaignContactBin'], y =dfbin['Success'])

# %% [markdown]
# **The Highest Success Rate Is at The First Contact of The Campaign, The Rest Has A Relatively Lower Success Rate**
#
#     This Indicate That Some Customers Wouldn't Change Their First Response
#
# **Previously Contacted Customers Has A Far Higher of Successful Campaign Rate**
#
#     As Shown Below, The Customers That Put Term Deposits on Previous Campaign, Have More Average Previous Contact History
#
#     This Is Some of Recurring Customers But There Might Be Some Other Factors Such As Familiarity And Trust
#
#     Previous Contact Existence Are Signs, The Person Has Already Been A Loyal Customer At Least Since The Previous Campaign

# %%
img11 = mpimg.imread('Image/Trust.JPG')
plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
sns.barplot(data = df, x=df['PreviousOutcome'], y =df['PreviousCampaignContact'])
plt.subplot(1,2,2)
plt.axis('off')
imgplot = plt.imshow(img11)

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.barplot(data = df, x=df['PreviousCampaignContact'], y =df['Age'])
plt.subplot(1,2,2)
sns.barplot(data = df, x=df['PreviousCampaignContact'], y =df['Job'])

# %% [markdown]
# **Previously Contacted Customers Tend To Be Older Than Customers That Has No Prior Contact**
#
#     This Increases The Rate of Successful Campaign on Previously Contacted Customers, as Older People Has Higher Saving Rate
#
# **On Previous Campaign, Students Are Contacted The Most**
#
#     This Also Increases The Rate of Successful Campaign on Previously Contacted Customers, as on Previous Campaign, Students Has A High Probability on Putting Term Deposits

# %% [markdown]
# # Analysis on Contact Days and Months

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
sns.barplot(data = df, x=df['ContactDay'], y =df['Success'])
plt.subplot(1,2,2)
sns.barplot(data = df, x=df['ContactMonth'], y =df['Success'])

# %% [markdown]
# **Monday And Friday Has The Least Successful Campaign Rate**
#
#    - This Might Be Linked To A Psychological "Mid-Week of Weekdays" Factor, But Still Unclear And Need A Further Research
#        - Journal Referrence : https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0134555
#
# **March, September ,October And December Are The Months With Highest Rate of Successful Campaign**
#
#     But Despite The Higher Rate Of Successful Campaign, The Total Number Of Successful Campaigns Still Less Than Average
#
# **May, June, July, August, And November Are The Months With Lowest Rate of Successful Campaign**
#
#     This Due To Lower Rate Of Savings During Summer, And Too Much Uneffective Contact Performed
#
#     But Despite The Lower Rate Of Successful Campaign, The Total Number Of Successful Campaigns Are More Than Average

# %%
img12 = mpimg.imread('Image/MidWeekWeekdays.png')

plt.figure(figsize=(16, 3))
plt.subplot(1,1,1)
plt.axis('off')
plt.title('Mid-Week on Weekdays Performance Research')
imgplot = plt.imshow(img12)
plt.show()
plt.figure(figsize=(16, 7))
plt.subplot(1,1,1)
plt.axis('off')
imgplot = plt.imshow(img4)
plt.show()

plt.figure(figsize=(16, 4))
plt.subplot(1,3,1)
plt.axis('off')
plt.subplot(1,3,2)
labels = 'May', 'Jul', 'Aug', 'Jun', 'Nov', 'Apr', 'Oct', 'Sep', 'Mar', 'Dec'
colors = ['lightblue', 'brown', 'white', 'cyan', 'yellow', 'purple', 'lightgreen', 'orange', 'blue']
plt.pie(df['ContactMonth'].value_counts(), labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=0)
plt.axis('off')
plt.title('Campaign Month')
plt.show()
print('More Calls Performed During May, June, July, August And November')
print(' ')

(pd.crosstab(index=df['Success'], columns=df['ContactMonth'], normalize=True)*100).round(2)
# Out:
# More Calls Performed During May, June, July, August And November
# ContactMonth   apr    aug   dec    jul    jun   mar    may   nov   oct   sep
# Success
# 0             5.08  13.41  0.23  15.84  11.55  0.66  31.28  8.95  0.98  0.76
# 1             1.31   1.59  0.22   1.58   1.36  0.67   2.15  1.01  0.76  0.62

# %% [markdown]
# # Analysis on Contact Type And Contact Day

# %%
celullar_day = pd.crosstab(index=[df['ContactType'][df['ContactType']=='Celullar'],df['Success']], columns=df['ContactDay'], normalize="columns")
telephone_day = pd.crosstab(index=[df['ContactType'][df['ContactType']=='Telephone'],df['Success']], columns=df['ContactDay'], normalize="columns")
contact_day = pd.crosstab(index=df['Success'], columns=df['ContactDay'], normalize="columns")

# %%
plt.figure(figsize=(16,3))

plt.subplot(1,3,1)
sns.heatmap(celullar_day, annot=True)
plt.title('Celullar')

plt.subplot(1,3,2)
sns.heatmap(telephone_day, annot=True)
plt.title('Telephone')

plt.subplot(1,3,3)
sns.heatmap(contact_day, annot=True)
plt.title('Contact')

plt.show()

# %% [markdown]
# **Monday And Friday Are The Least Successful Day To Perform The Campaign on Both Telephone And Celullar**

# %% [markdown]
# # Analysis on Job And Contact Day

# %%
admin_day = pd.crosstab(index=[df['Job'][df['Job']=='admin.'],df['Success']], columns=df['ContactDay'], normalize="columns")
bc_day = pd.crosstab(index=[df['Job'][df['Job']=='blue-collar'],df['Success']], columns=df['ContactDay'], normalize="columns")
technician_day = pd.crosstab(index=[df['Job'][df['Job']=='technician'],df['Success']], columns=df['ContactDay'], normalize="columns")
services_day = pd.crosstab(index=[df['Job'][df['Job']=='services'],df['Success']], columns=df['ContactDay'], normalize="columns")
management_day = pd.crosstab(index=[df['Job'][df['Job']=='management'],df['Success']], columns=df['ContactDay'], normalize="columns")
retired_day = pd.crosstab(index=[df['Job'][df['Job']=='retired'],df['Success']], columns=df['ContactDay'], normalize="columns")
entrepreneur_day = pd.crosstab(index=[df['Job'][df['Job']=='entrepreneur'],df['Success']], columns=df['ContactDay'], normalize="columns")
se_day = pd.crosstab(index=[df['Job'][df['Job']=='self-employed'],df['Success']], columns=df['ContactDay'], normalize="columns")
housemaid_day = pd.crosstab(index=[df['Job'][df['Job']=='housemaid'],df['Success']], columns=df['ContactDay'], normalize="columns")
unemployed_day = pd.crosstab(index=[df['Job'][df['Job']=='unemployed'],df['Success']], columns=df['ContactDay'], normalize="columns")
student_day = pd.crosstab(index=[df['Job'][df['Job']=='student'],df['Success']], columns=df['ContactDay'], normalize="columns")
unknown_day = pd.crosstab(index=[df['Job'][df['Job']=='unknown'],df['Success']], columns=df['ContactDay'], normalize="columns")
alljob_day = pd.crosstab(index=df['Success'], columns=df['ContactDay'], normalize="columns")

# %%
plt.figure(figsize=(16,3))

plt.subplot(1,2,1)
sns.heatmap(admin_day, annot=True)
plt.title('Admin')

plt.subplot(1,2,2)
sns.heatmap(bc_day, annot=True)
plt.title('Blue Collar')

plt.show()

plt.figure(figsize=(16,3))

plt.subplot(1,2,1)
sns.heatmap(technician_day, annot=True)
plt.title('Technician')

plt.subplot(1,2,2)
sns.heatmap(management_day, annot=True)
plt.title('Management')

plt.show()

plt.figure(figsize=(16,3))

plt.subplot(1,2,1)
sns.heatmap(retired_day, annot=True)
plt.title('Retired')

plt.subplot(1,2,2)
sns.heatmap(entrepreneur_day, annot=True)
plt.title('Entrepreneur')

plt.show()

plt.figure(figsize=(16,3))

plt.subplot(1,2,1)
sns.heatmap(se_day, annot=True)
plt.title('Self Employed')

plt.subplot(1,2,2)
sns.heatmap(housemaid_day, annot=True)
plt.title('Housemaid')

plt.show()

plt.figure(figsize=(16,3))

plt.subplot(1,2,1)
sns.heatmap(unemployed_day, annot=True)
plt.title('Unemployed')

plt.subplot(1,2,2)
sns.heatmap(student_day, annot=True)
plt.title('Student')

plt.show()

plt.figure(figsize=(16,3))

plt.subplot(1,2,1)
sns.heatmap(unknown_day, annot=True)
plt.title('Unknown')

plt.subplot(1,2,2)
sns.heatmap(alljob_day, annot=True)
plt.title('All Job')

plt.show()

# %% [markdown]
# **Each Job Groups Had Different Best Day To Perform The Contact**
#
# **On Average, Mid-Week of Weekdays Are The Best Time To Perform The Contact**

# %% [markdown]
# # Analysis on Job And Contact Month

# %%
admin_month = pd.crosstab(index=[df['Job'][df['Job']=='admin.'],df['Success']], columns=df['ContactMonth'], normalize="columns")
bc_month = pd.crosstab(index=[df['Job'][df['Job']=='blue-collar'],df['Success']], columns=df['ContactMonth'], normalize="columns")
technician_month = pd.crosstab(index=[df['Job'][df['Job']=='technician'],df['Success']], columns=df['ContactMonth'], normalize="columns")
services_month = pd.crosstab(index=[df['Job'][df['Job']=='services'],df['Success']], columns=df['ContactMonth'], normalize="columns")
management_month = pd.crosstab(index=[df['Job'][df['Job']=='management'],df['Success']], columns=df['ContactMonth'], normalize="columns")
retired_month = pd.crosstab(index=[df['Job'][df['Job']=='retired'],df['Success']], columns=df['ContactMonth'], normalize="columns")
entrepreneur_month = pd.crosstab(index=[df['Job'][df['Job']=='entrepreneur'],df['Success']], columns=df['ContactMonth'], normalize="columns")
se_month = pd.crosstab(index=[df['Job'][df['Job']=='self-employed'],df['Success']], columns=df['ContactMonth'], normalize="columns")
housemaid_month = pd.crosstab(index=[df['Job'][df['Job']=='housemaid'],df['Success']], columns=df['ContactMonth'], normalize="columns")
unemployed_month = pd.crosstab(index=[df['Job'][df['Job']=='unemployed'],df['Success']], columns=df['ContactMonth'], normalize="columns")
student_month = pd.crosstab(index=[df['Job'][df['Job']=='student'],df['Success']], columns=df['ContactMonth'], normalize="columns")
unknown_month = pd.crosstab(index=[df['Job'][df['Job']=='unknown'],df['Success']], columns=df['ContactMonth'], normalize="columns")
alljob_month = pd.crosstab(index=df['Success'], columns=df['ContactMonth'], normalize="columns")

# %%
plt.figure(figsize=(16,3))
plt.subplot(1,2,1)
sns.heatmap(admin_month, annot=True)
plt.title('Admin')
plt.subplot(1,2,2)
sns.heatmap(bc_month, annot=True)
plt.title('Blue Collar')
plt.show()

plt.figure(figsize=(16,3))
plt.subplot(1,2,1)
sns.heatmap(technician_month, annot=True)
plt.title('Technician')
plt.subplot(1,2,2)
sns.heatmap(management_month, annot=True)
plt.title('Management')
plt.show()

plt.figure(figsize=(16,3))
plt.subplot(1,2,1)
sns.heatmap(retired_month, annot=True)
plt.title('Retired')
plt.subplot(1,2,2)
sns.heatmap(entrepreneur_month, annot=True)
plt.title('Entrepreneur')
plt.show()

plt.figure(figsize=(16,3))
plt.subplot(1,2,1)
sns.heatmap(se_month, annot=True)
plt.title('Self Employed')
plt.subplot(1,2,2)
sns.heatmap(housemaid_month, annot=True)
plt.title('Housemaid')
plt.show()

plt.figure(figsize=(16,3))
plt.subplot(1,2,1)
sns.heatmap(unemployed_month, annot=True)
plt.title('Unemployed')
plt.subplot(1,2,2)
sns.heatmap(student_month, annot=True)
plt.title('Student')
plt.show()

plt.figure(figsize=(16,3))
plt.subplot(1,2,1)
sns.heatmap(unknown_month, annot=True)
plt.title('Unknown')
plt.subplot(1,2,2)
sns.heatmap(alljob_month, annot=True)
plt.title('All Job')
plt.show()

# %% [markdown]
# **Each Job Groups Had Different Best Month To Perform The Contact**
#
# **On Average, March, September, October, And December Are The Best Time To Perform The Contact**

# %% [markdown]
# # Analysis on Age Group And Contact Month

# %%
elder_month = pd.crosstab(index=[dfbin['AgeGroup'][dfbin['AgeGroup']=='Elder'],dfbin['Success']], columns=dfbin['month_full'], normalize="columns")
senior_month = pd.crosstab(index=[dfbin['AgeGroup'][dfbin['AgeGroup']=='Senior'],dfbin['Success']], columns=dfbin['month_full'], normalize="columns")
middle_month = pd.crosstab(index=[dfbin['AgeGroup'][dfbin['AgeGroup']=='Middle Age'],dfbin['Success']], columns=dfbin['month_full'], normalize="columns")
yadult_month = pd.crosstab(index=[dfbin['AgeGroup'][dfbin['AgeGroup']=='Young Adult'],dfbin['Success']], columns=dfbin['month_full'], normalize="columns")

# %%
plt.figure(figsize=(16,3))

plt.subplot(1,2,1)
sns.heatmap(elder_month, annot=True)
plt.title('Elder')

plt.subplot(1,2,2)
sns.heatmap(senior_month, annot=True)
plt.title('Senior')

plt.show()

plt.figure(figsize=(16,3))

plt.subplot(1,2,1)
sns.heatmap(middle_month, annot=True)
plt.title('Middle Age')

plt.subplot(1,2,2)
sns.heatmap(yadult_month, annot=True)
plt.title('Young Adult')

plt.show()

# %% [markdown]
# **November, July, And June Are The Best Month To Perform The Contact For Elders**
#
# **March, September, October, And December Are The Best Month To Perform The Contact On Senior, Middle Age, And Young Adult**

# %% [markdown]
# # Analysis on Economic Factor

# %%
plt.figure(figsize=(16,6))


plt.subplot(2,2,1)
sns.barplot(data = dfbin, x=dfbin['EuriborRate3Month'], y =dfbin['Success'])

plt.subplot(2,2,2)
sns.barplot(data = dfbin, x=dfbin['NumberOfEmployees'], y =dfbin['Success'])

# %%
img12 = mpimg.imread('Image/InkedEuriborRate.JPG')
img13 = mpimg.imread('Image/PortugalDepositInterestRate.JPG')
img14 = mpimg.imread('Image/PortugalWorkingAgePopulation.png')
plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
plt.axis('off')
imgplot = plt.imshow(img12)
plt.title('Portugal Euribor Rate')
plt.subplot(1,2,2)
plt.axis('off')
imgplot = plt.imshow(img13)
plt.show()

plt.figure(figsize=(16,3))
plt.subplot(1,2,1)
sns.barplot(data = dfbin, x=dfbin['NumberOfEmployeesBin'], y =dfbin['ThisCampaignContact'])
plt.subplot(1,2,2)
plt.axis('off')
plt.title('Portugal Working Age Population')
imgplot = plt.imshow(img14)

# %% [markdown]
# **The Successful Campaign Rate Is Lower During Higher Euribor Rate**
#
#     Euribor Is The Average Rates of Interbank Borrowing Rates Based on Supply And Demand
#
#     The Raise And Lower Interest Rate For Bank Customers, Mirrors Euribor Rates
#
#     High Euribor Rates Is A Sign on Low Saving Rates
#
#     When Borrowings Are High And Saving Rates Are Low, Euribor And Bank Rates Is Raised to Make Borrowings More Expensive
#
# **Lower Saving Rates Causes Euribor To Raise, Vice Versa**
#
# **Successful Campaign Rate Are Lower During Higher Number Of Employee**
#
#     This Is Because Too Many Calls Performed on The Same Customers
#
#     As Shown Before, 2nd Call And More Has Lower Rate Of Successful Campaign
#
# **The Number of Employee Are Volatile During 2008-2010, This Is Due To Extreme Economic Factors, Not Working Population Changes**

# %% [markdown]
# # Conclusion
#
# **Based on this data:**
#
# - **11.27% of contacted clients are willing to put a term deposits**
#
#
# - **Elderly group are the most willing to put a term deposits, followed by young adult, senior, and middle age**
#
#     Success Rate :
#     - 46.84% of elderly group (age 65+)
#     - 15.22% of young adult group (age 17-30)
#     - 12.07% of senior group (age 51-65)
#     - 9.14% of middle age group (age 31-50)
#
#
# - **Students are the most willing to put a term deposits, followed by retired people, unemployed, and others**
#
#     Success Rate :
#     - 31.43% of students
#     - 25.23% of retired
#     - 14.20% of unemployed
#     - 12.97% of admin
#     - 11.22% of management
#     - 10.83% of technician
#     - 10.49% of self employed
#     - 10% of housemaid
#     - 8.52% of entrepreneur
#     - 8.14% of services
#     - 6.89% of blue collar
#
#
# - **Person with higher education is more likely to put a term deposits**
#
#     Success Rate :
#     - 13.00% university degree or equal
#     - 10.15% basic 9 year education
#     - 9.52%  lower than basic 9 year education
#
#
# - **Married person is less likely to put a term deposits**
#
#     Success Rate :
#     - 10.32% divorced (including widowed)
#     - 14.00% single
#     - 15.00% unstated/unknown
#
#
# - **Person with no credit default are more likely to put a term deposits**
#
#     Success Rate :
#     - 12.88% with no credit default
#     - 5.15% unknown/unstated
#     - 0.00% with credit default
#
#
# - **Person with housing loan is slightly more likely to put a term deposits**
#
#     Success Rate :
#     - 11.61% with housing loan
#     - 10.88% without housing loan
#     - 10.80% unknown/unstated
#
#
# - **Person who has no loan is slightly more likely to put a term deposits**
#
#     Success Rate :
#     - 11.34% no loan
#     - 10.93% has loan
#     - 10.80% unknown/unstated
#
#
# - **Person who put a term deposits in previous campaign are very likely to put another term deposits**
#
#     Success Rate :
#     - 65.11% accepted the previous offer
#     - 14.22% rejected the previous offer
#     - 8.83% no previous offer
#
#
# - **Person contacted once is more likely to put a term deposits**
#
#     Success Rate :
#     - 13.03% contacted once
#     - 11.45% contacted twice
#     - 10.75% contacted three times
#     - 7.27% contacted more than three times
#
#
# - **Person contacted on other campaign are more likely to put a term deposits**
#
#     Success Rate :
#     - 58.70% contacted more than twice on other campaign
#     - 46.41% contacted twice on other campaign
#     - 21.20% contacted once on other campaign
#     - 8.83% has never been contacted on other campaign
#
#
# - **Person who are contacted via cellular are more likely to put a term deposits**
#
#     Success Rate :
#     - 14.74% via cellular
#     - 5.23% via telephone
#
#
# - **Thursday is the best day to contact customers, followed by Tuesday, Wednesday, Friday and Monday**
#
#     Success Rate :
#     - 12.12% Thursday
#     - 11.78% Tuesday
#     - 11.67% Wednesday
#     - 10.80% Friday
#     - 9.94% Monday
#
#
# - **1st Quarter of the year, is the best time to contact customers, followed by 4th, 3rd and 2nd **This due to saving rate spike during March, September, October and December**
#
#     Success Rate :
#     - 50.55% 1st Quarter
#     - 16.40% 4th Quarter
#     - 11.20% 3rd Quarter
#     - 9.13% 2nd Quarter
#
#
# - **March, September, October, and December are among the best months to contact customers**
# - **May, June, and July are among the worst months to contact customers**
#
#     Success Rate :
#     - 50.54% March
#     - 48.90% December
#     - 44.91% September
#     - 43.87% October
#     - 20.47% April
#     - 10.60% August
#     - 10.51% June
#     - 10.14% November
#     - 9.04% July
#     - 6.43% May
#
#
# - **Successful campaign rate are higher during lower euribor rate**
#
#     Success Rate :
#     - 44.68% during 2.0 euribor rate
#     - 24.02% during 1.0 euribor rate
#     - 20.00% during 3.0 euribor rate
#     - 5.03% during 4.0 euribor rate
#     - 4.80% during 5.0 euribor rate
